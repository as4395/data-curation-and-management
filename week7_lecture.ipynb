# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib

# %%
import kagglehub

# %%
path = kagglehub.dataset_download("sumanthvrao/daily-climate-time-series-data")

# %%
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/abhiramsingireddy/.cache/kagglehub/datasets/sumanthvrao/daily-climate-time-series-data/versions/3

# %%
path = r"/Users/abhiramsingireddy/.cache/kagglehub/datasets/sumanthvrao/daily-climate-time-series-data/versions/3"
filepath = pathlib.Path(path)
file = filepath/"DailyDelhiClimateTest.csv"
df = pd.read_csv(file)

df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1  2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2  2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3  2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4  2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %%
df.plot(x='date', y='humidity', xlabel = 'Date', ylabel='Humidity')
plt.show()

# %%
df.plot.line(x='date',y='meanpressure')
# Out:
# <Axes: xlabel='date'>

# %%
path = kagglehub.dataset_download("brendan45774/test-file")

# %%
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/abhiramsingireddy/.cache/kagglehub/datasets/brendan45774/test-file/versions/6

# %%
path = r"/Users/abhiramsingireddy/.cache/kagglehub/datasets/brendan45774/test-file/versions/6"
filepath = pathlib.Path(path)
file = filepath/"tested.csv"
df = pd.read_csv(file)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    418.000000  418.000000  418.000000               418   418
# unique          NaN         NaN         NaN               418     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   266
# mean    1100.500000    0.363636    2.265550               NaN   NaN
# std      120.810458    0.481622    0.841838               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.250000    0.000000    1.000000               NaN   NaN
# 50%     1100.500000    0.000000    3.000000               NaN   NaN
# 75%     1204.750000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   332.000000  418.000000  418.000000       418  417.000000
# ...

# %%
genders = df['Sex'].value_counts()

genders
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
genders.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].unique()
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
df['Boarded'] = df['Embarked'].replace({'Q':'Queenstown','S':'Southampton','C':'Cherbourg'})

# %%
boarded_counts = df['Boarded'].value_counts()

boarded_counts.plot.bar()
# Out:
# <Axes: xlabel='Boarded'>

# %%
df.plot.scatter(x='Age',y='Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
df['Age'].plot(kind='hist', bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Fare'].plot(kind='box')
# Out:
# <Axes: >
